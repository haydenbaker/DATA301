# %% [markdown]
# # Exam 1 Info
#
# Exam 1 will be in class on Tuesday, February 5. You will have the entire class period (170 minutes) to complete the exam. It is open-book, open-Internet. The only rule is that you cannot communicate with another person during the exam.
#
# Your Exam 1 will consist of eight questions about a data set of used cars, available here: `https://raw.githubusercontent.com/dlsun/data-science-book/master/data/usedcars.csv`. I encourage you to explore this data set, come up with interesting questions, and answer those questions to prepare for the exam.
#
# Good luck!

# %%
import pandas as pd
# %matplotlib inline

# %%
cars_df = pd.read_csv("https://raw.githubusercontent.com/dlsun/data-science-book/master/data/usedcars.csv")

# %%
cars_df[["City", "State", "Make", "Model"]] = cars_df[["City", "State", "Make", "Model"]].apply(lambda s: s.str.upper())
cars_df
# Out:
#        Price  Year  Mileage              City State                Vin  \
# 0      27947  2010    84925       SAN ANTONIO    TX  JTJJM7FX5A5009042
# 1      16850  2010    76863        RICHARDSON    TX  WDDHF5GB9AA106034
# 2      34974  2017     9978     BUFFALO GROVE    IL  1FM5K8F82HGC23716
# 3      28997  2014    40480      WILLIAMSBURG    VA  1C4RJFBG9EC506630
# 4      12499  2015    21849     DOWNERS GROVE    IL  1FADP3K24FL209932
# 5      41988  2014    17383            BUFORD    GA  ZAM57RTA9E1096380
# 6       4950  2004   115189    VIRGINIA BEACH    VA  4M2ZU86W24UJ03659
# 7      22495  2016    33049         MILLSBORO    DE  1FATP8EM7G5280912
# 8      10295  2013    57300         NAUGATUCK    CT  4S3BMBA68D3038611
# 9      16991  2015    36393            TUCSON    AZ  1G11C5SL2FF197378
# 10     34950  2015    17532        SMITHFIELD    NC  2C3CDZFJ6FH820808
# 11     19912  2016    20620      EAST HANOVER    NJ  NM0GE9F70G1248677
# 12     19621  2013    41333        NAPERVILLE    IL  JN1CV6AR6DM357618
# 13     18491  2016    36729              LUTZ    FL  2C3CDXHG1GH187058
# 14     24995  2014    19996      INDIANAPOLIS    IN  2GKFLWEK2E6360517
# 15     23990  2014    35483    FREDERICKSBURG    VA  JN1BV7AP8EM692073
# 16      7455  2010   154917         HILLSBORO    OR  2T1BU4EE1AC427901
# 17     15478  2010    58650          LYNBROOK    NY  JTEZK3EH8A2103895
# 18     14620  2013    56617           READING    PA  1N4AL3AP9DC147548
# 19      9550  2009    97409              NOVI    MI  2FMDK49C29BA34299
# 20      5495  2004   138000            PUTNAM    CT  JN8AZ08W44W305365
# 21     11595  2015    38484          BLAUVELT    NY  1N4AL3AP0FN376174
# 22     21900  2014    23947           WINDSOR    CO  WVWHD7AJ1EW005073
# 23     22695  2017    25024       SANTA CLARA    CA  2GKALPEK8H6139122
# 49997  37564  2016    10051        BUENA PARK    CA  5TDYKRFH7GS131173
# 49998  25999  2015    29944     MECHANICSBURG    PA  2C3CDXJG0FH863847
# 49999   8999  2012    91308           HOUSTON    TX  4A32B3FF4CE024595
#
#                 Make               Model
# 0              LEXUS                  GX
# 1      MERCEDES-BENZ          E-CLASS4DR
# 2               FORD         EXPLORER4WD
# 3               JEEP               GRAND
# 4               FORD      FOCUSHATCHBACK
# 5           MASERATI        GHIBLIGHIBLI
# 6            MERCURY      MOUNTAINEER4DR
# 7               FORD  MUSTANGCONVERTIBLE
# 8             SUBARU          LEGACY2.5I
# 9          CHEVROLET           MALIBU1LT
# 10             DODGE       CHALLENGERR/T
# 11              FORD             TRANSIT
# 12          INFINITI                 G37
# 13             DODGE          CHARGERSXT
# 14               GMC          TERRAINAWD
# 15          INFINITI              Q50RWD
# 16            TOYOTA          COROLLA4DR
# 17            TOYOTA       HIGHLANDERFWD
# 18            NISSAN         ALTIMASEDAN
# 19              FORD             EDGE4DR
# 20            NISSAN           MURANO4DR
# 21            NISSAN           ALTIMA2.5
# 22        VOLKSWAGEN           GTI4-DOOR
# 23               GMC          TERRAINFWD
# 24     MERCEDES-BENZ     CLS-CLASSCLS550
# 25          CHRYSLER              2004DR
# 26             HONDA              ACCORD
# 27               KIA           SORENTOLX
# 28              FORD            F-1502WD
# 29               BMW                   5
# ...              ...                 ...
# 49970            RAM             35004WD
# 49971            BMW         X5XDRIVE35D
# 49972          DODGE          CHARGERSXT
# 49973            KIA           SORENTOEX
# 49974           FORD         EXPLORERXLT
# 49975          HONDA               CIVIC
# 49976          DODGE          JOURNEYSXT
# 49977         NISSAN           ALTIMA2.5
# 49978      CHEVROLET        AVALANCHE4WD
# 49979          BUICK       ENCORELEATHER
# 49980           FORD      FOCUSHATCHBACK
# 49981          DODGE       CHALLENGER2DR
# 49982       CADILLAC      SRXPERFORMANCE
# 49983           FORD        MUSTANGCOUPE
# 49984           FORD           ESCAPE4WD
# 49985          DODGE              DARTGT
# 49986         SUBARU          OUTBACK4DR
# 49987            BMW                   2
# 49988            KIA       SOULAUTOMATIC
# 49989           JEEP               GRAND
# 49990         TOYOTA       HIGHLANDERFWD
# 49991      CHEVROLET               CRUZE
# 49992          DODGE       CHALLENGERSXT
# 49993            GMC           ACADIAAWD
# 49994     MITSUBISHI           OUTLANDER
# 49995            KIA            OPTIMASX
# 49996          BUICK          ENCLAVEAWD
# 49997         TOYOTA       HIGHLANDERFWD
# 49998          DODGE          CHARGERSXT
# 49999     MITSUBISHI           GALANT4DR
#
# [50000 rows x 8 columns]
